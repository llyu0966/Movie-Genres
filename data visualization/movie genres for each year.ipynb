# %%
import pandas as pd

# %%
import plotly.express as px

# %%
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('movies.csv')

# %%
data
# Out:
#      Year  Film_Noir  Action  Adventure  Horror  Romance  War  Western  \
# 0    1902          0       1          1       0        0    0        0
# 1    1903          0       0          0       0        0    0        1
# 2    1908          0       0          0       0        0    0        0
# 3    1915          0       0          0       0        0    1        0
# 4    1916          0       1          1       0        1    0        0
# ..    ...        ...     ...        ...     ...      ...  ...      ...
# 102  2014          0      61         35      27       35    8        3
# 103  2015          0      63         45      36       21    2        4
# 104  2016          0      48         36      16       18    3        1
# 105  2017          0      38         24      13        6    3        2
# 106  2018          0      16         12       4        1    0        0
#
#      Documentary  Sci-Fi  ...  no_genres_listed  Crime  Fantasy  Animation  \
# ...

# %%
# show the general distribution of number of movies per year.

# %%
y = data['Total']
x = data['Year']

plt.xlabel('Year')
plt.ylabel('Total')

# %%
plt.scatter(x,y)

# %%
plt.plot(data.Year, data.Total)

plt.show()

# %%
plt.title('Number of Movies for per Genre(per Year)')

plt.plot(data.Year, data.Total, label='Total')
plt.plot(data.Year, data.Action, label='Action')
plt.plot(data.Year, data['Film_Noir'], label='Film_Noir')
plt.plot(data.Year, data.Adventure, label='Adventure')
plt.plot(data.Year, data.Horror, label='Horror')

plt.xticks(data.Year)

plt.legend()

plt.show()

# %%
plt.title('Number of Movies for per Genre(per Year)')

plt.plot(data.Year, data.Total, label='Total')
plt.plot(data.Year, data.Action, label='Action')
plt.plot(data.Year, data['Film_Noir'], label='Film_Noir')
plt.plot(data.Year, data.Adventure, label='Adventure')
plt.plot(data.Year, data.Horror, label='Horror')

# iterator every decade
print(data.Year[::10])

plt.xticks(data.Year[::10])

plt.legend()

plt.show()
# Out:
# 0      1902
# 10     1923
# 20     1933
# 30     1943
# 40     1953
# 50     1963
# 60     1973
# 70     1983
# 80     1993
# 90     2003
# 100    2012
# Name: Year, dtype: object

# %%
plt.title('Number of Movies for per Genre(per Year)')

for genre in data:
    if genre != 'Year':
        if genre != 'Total':
          plt.plot(data.Year, data[genre], marker = '.', label = genre)
    
# iterator every decade
print(data.Year[::10])

plt.xticks(data.Year[::10])

plt.legend()

plt.show()
# Out:
# 0      1902
# 10     1923
# 20     1933
# 30     1943
# 40     1953
# 50     1963
# 60     1973
# 70     1983
# 80     1993
# 90     2003
# 100    2012
# Name: Year, dtype: object

# %%
bins = [0,50,100,150,200,250,300,350,400,450,500,550,600,650,700,750,800]

plt.hist(data.Total, bins=bins)

plt.xticks(bins)

plt.ylabel('Number of Years')
plt.xlabel('Total Number of Movies Each Year')

plt.show()
